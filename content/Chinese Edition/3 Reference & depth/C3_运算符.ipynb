// %% [markdown]
// # 运算符
//
// _本笔记本涵盖: 运算符_

// %% [markdown]
// ## ✏️ 知识点讲解
//
// (在这里写理论部分...)

// %%
// 示例 C 代码片段
#include <stdio.h>
int main() {
    printf("你好，C语言！\n");
    return 0;
}

// %% [markdown]
// ## 🎯 练习
//
// 1. 编写一个简单的程序 ...
// 2. 修改示例代码 ...
