# %% [markdown]
# # 小游戏编程
#
# _本笔记本涵盖: 小游戏编程_

# %% [markdown]
# ## ✏️ 知识点讲解
#
# (在这里写理论部分...)

# %%
// 示例 C 代码
#include <stdio.h>
int main() {
    // 在这里完成任务
    return 0;
}

# %% [markdown]
# ## 🎯 实践任务
#
# 1. 尝试编写一个相关的小程序 ...
# 2. 扩展示例代码 ...
